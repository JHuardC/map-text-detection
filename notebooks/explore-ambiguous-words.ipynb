# %% [markdown]
# # Inspecting ambiguous word instances from overlapping image patches using word only text spotter

# %%
from typing import Final
from pathlib import Path
from os import getenv
from dotenv import find_dotenv, load_dotenv
from geopandas import read_file

PROJECT_DIR: Final[Path] = Path(find_dotenv(".env", 1, 1)).absolute().parent
load_dotenv(PROJECT_DIR.joinpath(".env"))
LOCAL_DIR: Final[Path] = Path(getenv("LOCAL_DIR"))
AMBIGUOUS_DIR = LOCAL_DIR\
    .joinpath("outputs/manual-labelling/merge-trial/processed-words/ambiguous")

ambiguous_cliques = read_file(AMBIGUOUS_DIR.joinpath("glam-st17ne-2-cliques.gpkg"))

# %%
ambiguous_cliques
